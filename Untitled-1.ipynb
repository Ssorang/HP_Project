# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/s0rang/HP_Project/sj_covid.xlsx")

# %%
df.head()
# Out:
#             연번 학생/교직원         확진일 학교급   학년    반/부서    번호    생년월일     학교명  \
# 0  23160207740    교직원  2023-03-01   초  NaN  성주초등학교   NaN  770306  성주초등학교
# 1  23160206637    교직원  2023-01-10   초  NaN  성주초등학교   NaN     219  성주초등학교
# 2  22160205303     학생  2022-12-28   초  4.0       2  14.0  121212  성주초등학교
# 3  22160204922     학생  2022-12-26   초  4.0       2   2.0  121205  성주초등학교
# 4  22160204533     학생  2022-12-24   초  4.0       4   7.0  121011  성주초등학교
#
#          학교코드   성명        해제일자                 등록일시               등록자  비고
# 0  R100002230  여상숙  2023-03-08  2023-03-02 11:31:18     최금옥(kochoi66) NaN
# 1  R100002230  이상민  2023-01-16  2023-01-10 17:11:02  이상민(eksajrm0624) NaN
# 2  R100002230  유상범  2023-01-03  2022-12-28 10:07:48  유상범(eksajrm0624) NaN
# 3  R100002230  김창현  2023-01-02  2022-12-27 08:33:05   김창현(2022000248) NaN
# 4  R100002230  여순천  2022-12-30  2022-12-26 09:10:40  여순천(eksajrm0624) NaN

# %%
data = df.sort_values(by="확진일") # 날짜 기준으로 정렬
data.drop([0, 1], axis = 0, inplace = True)
data[['확진일','성명','학년', '반/부서']]
# Out:
#             확진일   성명   학년 반/부서
# 411  2022-03-01  이효민  1.0    2
# 408  2022-03-01  여예린  2.0    3
# 410  2022-03-01  김민준  5.0    2
# 409  2022-03-02  김서준  1.0    3
# 342  2022-03-02  장아윤  1.0    1
# ..          ...  ...  ...  ...
# 6    2022-12-16  이윤아  3.0    3
# 5    2022-12-20  이시영  5.0    3
# 4    2022-12-24  여순천  4.0    4
# 3    2022-12-26  김창현  4.0    2
# 2    2022-12-28  유상범  4.0    2
#
# [410 rows x 4 columns]

# %%
date = data[['확진일']]
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 410 entries, 411 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   확진일     410 non-null    object
# dtypes: object(1)
# memory usage: 6.4+ KB

# %%
date[['확진일']] = date[['확진일']].astype('str')
date
# Out:
# /var/folders/32/l16_j7w57n38ctxjy_vhk_5h0000gn/T/ipykernel_29688/2635805347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date[['확진일']] = date[['확진일']].astype('str')
#             확진일
# 411  2022-03-01
# 408  2022-03-01
# 410  2022-03-01
# 409  2022-03-02
# 342  2022-03-02
# ..          ...
# 6    2022-12-16
# 5    2022-12-20
# 4    2022-12-24
# 3    2022-12-26
# 2    2022-12-28
#
# [410 rows x 1 columns]

# %%
pd.to_datetime(date[['확진일']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb 셀 7 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X12sdW50aXRsZWQ%3D?line=0'>1</a> pd.to_datetime(date[['확진일']])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1115, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1115     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1116 elif isinstance(arg, Index):
#    1117     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...
